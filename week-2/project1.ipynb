# %%
import cmath

# Function to solve cubic equations: Ax^3 + Bx^2 + Cx + D = 0
def solve_cubic(A, B, C, D):
    # For simplicity, we will not solve cubic equations analytically, but rather use a numerical approach
    # You can use a general approach, like finding one root through trial and error (or a numerical method)
    # Here, we simply use a trial-and-error method (not the most efficient)
    # But for simplicity, we will just use an approach to show how the equation would be solved in real cases.
    print("Cubic equation solving requires more complex methods.")
    return "Cubic equations require numerical methods or specialized formulas."

# Function to solve quartic equations: Ax^4 + Bx^3 + Cx^2 + Dx + E = 0
def solve_quartic(A, B, C, D, E):
    print("Quartic equation solving requires more complex methods.")
    return "Quartic equations require numerical methods or specialized formulas."

# Function to solve quadratic equations: Ax^2 + Bx + C = 0
def solve_quadratic(A, B, C):
    # Quadratic formula: x = (-B ± sqrt(B^2 - 4AC)) / 2A
    discriminant = B**2 - 4*A*C
    if discriminant > 0:
        root1 = (-B + cmath.sqrt(discriminant)) / (2 * A)
        root2 = (-B - cmath.sqrt(discriminant)) / (2 * A)
        return root1, root2
    elif discriminant == 0:
        root = -B / (2 * A)
        return root,
    else:
        root1 = (-B + cmath.sqrt(discriminant)) / (2 * A)
        root2 = (-B - cmath.sqrt(discriminant)) / (2 * A)
        return root1, root2

def main():
    print("Welcome to the equation solver!")
    print("Please choose the type of equation to solve:")
    print("1. Cubic Equation (Ax^3 + Bx^2 + Cx + D = 0)")
    print("2. Quartic Equation (Ax^4 + Bx^3 + Cx^2 + Dx + E = 0)")
    print("3. Quadratic Equation (Ax^2 + Bx + C = 0)")

    choice = int(input("Enter the number corresponding to the equation: "))

    if choice == 1:
        A = float(input("Enter the coefficient A (for Ax^3): "))
        B = float(input("Enter the coefficient B (for Bx^2): "))
        C = float(input("Enter the coefficient C (for Cx): "))
        D = float(input("Enter the constant D: "))
        result = solve_cubic(A, B, C, D)
        print(result)

    elif choice == 2:
        A = float(input("Enter the coefficient A (for Ax^4): "))
        B = float(input("Enter the coefficient B (for Bx^3): "))
        C = float(input("Enter the coefficient C (for Cx^2): "))
        D = float(input("Enter the coefficient D (for Dx): "))
        E = float(input("Enter the constant E: "))
        result = solve_quartic(A, B, C, D, E)
        print(result)

    elif choice == 3:
        A = float(input("Enter the coefficient A (for Ax^2): "))
        B = float(input("Enter the coefficient B (for Bx): "))
        C = float(input("Enter the constant C: "))
        roots = solve_quadratic(A, B, C)
        print("The roots of the quadratic equation are:", roots)

    else:
        print("Invalid choice. Please select 1, 2, or 3.")

if __name__ == "__main__":
    main()
# Out:
# Welcome to the equation solver!
# Please choose the type of equation to solve:
# 1. Cubic Equation (Ax^3 + Bx^2 + Cx + D = 0)
# 2. Quartic Equation (Ax^4 + Bx^3 + Cx^2 + Dx + E = 0)
# 3. Quadratic Equation (Ax^2 + Bx + C = 0)
